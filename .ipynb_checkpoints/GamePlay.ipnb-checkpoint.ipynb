# %%
import competition_committee as cc
# import helper_competition
from kaggle_environments import evaluate
from helper_general import *
# Out:
# Loading environment football failed: No module named 'gfootball'

# %% [markdown]
# # Define your agent  below

# %%
# %%writefile players/Reactionary.py

import random
from kaggle_environments.envs.rps.utils import get_score

last_react_action = None
def reactionary(observation, configuration):
    global last_react_action
    if observation.step == 0:
        last_react_action = random.randrange(0, configuration.signs)
    elif get_score(last_react_action, observation.lastOpponentAction) <= 1:
        last_react_action = (observation.lastOpponentAction + 1) % configuration.signs

    return last_react_action
# Out:
# Overwriting players/Reactionary.py

# %%
# %%writefile players/Ensemble.py

def win_action(action):
    '''
    return the action that would win the given action
    '''
    return (action + 1)%3



opp_moves = []
my_moves = []

def agent(observation, configuration):
    return 0
# Out:
# Overwriting players/Ensemble.py

# %% [markdown]
# # Test Agent

# %%
trial_agent = 'players/' + 'Backtracker_ver2.py'

result =  evaluate(
            "rps", 
            ['players/SemiRandom.py', trial_agent],
            configuration={"episodeSteps": 1000})
print(result)
# Out:
# [[-110.0, 110.0]]

# %% [markdown]
# # Compete in the following

# %%
theGame  = cc.Competition()
theGame.players
# Out:
# ['copy_cat.py',
#  'Spinoza.py',
#  'paper_lover.py',
#  'Goldfish.py',
#  'Ensemble.py',
#  'rock_lover.py',
#  'Reactionary.py',
#  'scissors_lover.py']

# %%
theGame.compete(rounds= 5)
display(theGame.rank_players())
theGame.match_matrix()
# Out:
# HBox(children=(HTML(value='Competition'), FloatProgress(value=0.0, max=18.0), HTML(value='')))
#                                Agent  Score  Draw
# 3                         Spinoza.py   75.0   7.0
# 0          BlueBelt_Decision_Tree.py   73.0   5.0
# 1   BlackBelt_memory_patterns_v20.py   73.0   2.0
# 16            BlackBelt_Greenberg.py   67.0  19.0
# 7                        Goldfish.py   41.0  10.0
# 4                  BlueBelt_rfind.py   38.0   5.0
# 9                   Most_Frequent.py   37.0  10.0
# 8                      Psychology.py   36.0  12.0
# 17                    Reactionary.py   33.0  27.0
# 12                  random_player.py   32.0  35.0
# 10               nash_equilibrium.py   25.0  33.0
# 13                      tackleOCD.py   23.0  19.0
# 14                goldfish_killer.py   21.0  36.0
# 5                     paper_lover.py   13.0  10.0
# 2                        copy_cat.py   12.0   5.0
# 6                          bigram.py   10.0  16.0
# 15                     rock_lover.py    8.0  35.0
# 18                 scissors_lover.py    8.0  30.0
# 11                       Ensemble.py    7.0  17.0

# %%
model =  'goldfish_killer.py'
match_scores = theGame.prize_prez()
match_scores[(match_scores.P1 == model) | (match_scores.P2  == model)]
# Out:
# Empty DataFrame
# Columns: [P1, P2, P1 Score, P2 Score, Draw]
# Index: []
